# %% [markdown]
# # Part 3: Softmax Regression

# %%
# Execute this code block to install dependencies when running on colab
try:
    import torch
except:
    from os.path import exists
    from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
    platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
    cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
    accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

    # !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-1.0.0-{platform}-linux_x86_64.whl torchvision

# %% [markdown]
# In the second part of the lab we saw how to make a linear binary classifier using logisitic regression. In this  part of the lab we'll turn our attention to multi-class classification.
#
# Softmax regression (or multinomial logistic regression) is a generalisation of logistic regression to the case where we want to handle multiple classes. In logistic regression we assumed that the labels were binary: $y_i\in \{0,1\}$. We used such a classifier to distinguish between two kinds of hand-written digits. Softmax regression allows us to handle $y_i \in \{1,\dots,K\}$ where $K$ is the number of classes.
#
# Recall that in logistic regression, we had a training set $\{(\mathbf{x}_1,y_1),\dots,(\mathbf{x}_m,y_m)\}$ of $m$ labeled examples, where the input features are $\mathbf{x}_i \in \mathbb{R}^n$. In logistic regression, our hypothesis took the form:
#
# \begin{align}
# h_\theta(\mathbf{x}) &= \frac{1}{1 + \exp(-\mathbf{x}^\top\theta)} \equiv \sigma(\mathbf{x}^\top\theta)
# \end{align}
#
# and the model parameters $\theta$ were trained to minimise the cost function
#
# \begin{align}
# J(\theta) & = \sum_i y_i \log(\sigma(\mathbf{x}_i^\top\theta)) + (1-y_i) \log(1-\sigma(\mathbf{x}_i^\top\theta))
# \end{align}
#
# In the softmax regression setting, we are interested in multi-class classification, and so the label $y$
#  can take on $K$ different values, rather than only two. Thus, in our training set $\{(\mathbf{x}_1,y_1),\dots,(\mathbf{x}_m,y_m)\}$, we now have that $y_i \in \{1,\dots,K\}$.
#
# Given a test input $\mathbf{x}$, we want our hypothesis to estimate the probability that $P(y=k|\mathbf{x})$ for each value of $k=1,\dots,K$. That is to say, we want to estimate the probability of the class label taking on each of the $K$ different possible values. Thus, our hypothesis will output a $K$-dimensional vector (whose elements sum to 1) giving us our $K$ estimated probabilities. Concretely, our hypothesis $h_\theta(\mathbf{x})$ takes the form:
#
# \begin{align}
# h_\theta(\mathbf{x}) =
# \begin{bmatrix}
# P(y = 1 | \mathbf{x}; \theta) \\
# P(y = 2 | \mathbf{x}; \theta) \\
# \vdots \\
# P(y = K | \mathbf{x}; \theta)
# \end{bmatrix}
# =
# \frac{1}{ \sum_{j=1}^{K}{\exp(\theta^{(j)\top} \mathbf{x}) }}
# \begin{bmatrix}
# \exp(\theta^{(1)\top} \mathbf{x} ) \\
# \exp(\theta^{(2)\top} \mathbf{x} ) \\
# \vdots \\
# \exp(\theta^{(K)\top} \mathbf{x} ) \\
# \end{bmatrix}
# \end{align}
#
# Here $\theta^{(1)},\theta^{(2)},\dots,\theta^{(K)} \in \mathbb{R}^n$ are the parameters of our model. Notice that the term $\frac{1}{\sum_{j=1}^K exp(\theta^{(j)\top} \mathbf{x})}$ normalizes the distribution, so that it sums to one.
#
# For convenience, we will also write $\theta$ to denote all the parameters of our model. When you implement softmax regression, it is usually convenient to represent $\theta$ as a $n$-by-$K$ matrix obtained by concatenating $\theta_{(1)},\theta^{(2)},\dots,\theta^{(K)}$ into columns, so that
#
# \begin{align}
# \theta = \left[\begin{array}{cccc}| & | & | & | \\
# \theta^{(1)} & \theta^{(2)} & \cdots & \theta^{(K)} \\
# | & | & | & |
# \end{array}\right].
# \end{align}

# %% [markdown]
# ## Cost Function
#
# We now describe the cost function that we’ll use for softmax regression. In the equation below, $1\{\cdot\}$
#  is an "indicator function", such that $1\{\mathrm{a true statement}\}=1$, and $1\{\mathrm{a false statement}\}=0$. For example, $1\{2+2=4\}$ evaluates to $1$; whereas $1\{1+1=5\}$ evaluates to $0$. Our cost function will be:
#
# \begin{align}
# J(\theta) = - \left[ \sum_{i=1}^{m} \sum_{k=1}^{K}  1\left\{y_{i} = k\right\} \log \frac{\exp(\theta^{(k)\top} \mathbf{x}_i)}{\sum_{j=1}^K \exp(\theta^{(j)\top} \mathbf{x}_i)}\right]
# \end{align}
#
# Notice that this generalises the logistic regression cost function, which could also have been written:
#
# \begin{align}
# J(\theta) &= - \left[ \sum_{i=1}^m   (1-y^{(i)}) \log (1-h_\theta(\mathbf{x}_i)) + y^{(i)} \log h_\theta(\mathbf{x}_i) \right] \\
# &= - \left[ \sum_{i=1}^{m} \sum_{k=0}^{1} 1\left\{y^{(i)} = k\right\} \log P(y^{(i)} = k | \mathbf{x}_i ; \theta) \right]
# \end{align}
#
#
# The softmax cost function is similar, except that we now sum over the $K$ different possible values of the class label. Note also that in softmax regression, we have that
#
# \begin{equation}
# P(y_i = k | \mathbf{x}_i ; \theta) = \frac{\exp(\theta^{(k)\top} \mathbf{x}_i)}{\sum_{j=1}^K \exp(\theta^{(j)\top} \mathbf{x}_i) }
# \end{equation}
#
# We cannot solve for the minimum of $J(\theta)$ analytically, and thus we'll resort to using gradient descent as before. Taking derivatives, one can show that the gradient is:
#
# \begin{align}
# \nabla_{\theta^{(k)}} J(\theta) = - \sum_{i=1}^{m}{ \left[ \mathbf{x}_i \left( 1\{ y_i = k\}  - P(y_i = k | \mathbf{x}_i; \theta) \right) \right]  }
# \end{align}
#
# Armed with this formula for the derivative, one can then use it directly with a gradient descent solver (or any other 1st-order gradient based optimiser).

# %% [markdown]
# __Use the code box below to complete the implementation of the functions that return the gradients of the softmax loss function, $\nabla_{\theta^{(k)}} J(\theta) \,\, \forall k$ and the loss function itself, $J(\theta)$:__

# %%
import torch
import math

# we wouldn't normally do this, but for this lab we want to work in double precision
# as we'll need the numerical accuracy later on for doing checks on our gradients:
torch.set_default_dtype(torch.float64)

def cost_function(Theta, Xi, yi):
    num = math.e ** (Theta[:,yi].t() @ Xi)
    den = 0
    for th in Theta.t():
        den += math.e ** (th @ Xi)
    return num / den
  
def classes_probabilities(Theta, X, y):
    values = torch.exp(X @ Theta)
    sums = torch.sum(values, 1)
    return (values.t() / sums).t()

def softmax_regression_loss_grad(Theta, X, y):
    '''Implementation of the gradient of the softmax loss function.
    
    Theta is the matrix of parameters, with the parameters of the k-th class in the k-th column
    X contains the data vectors (one vector per row)
    y is a column vector of the targets
    '''
#    # YOUR CODE HERE
#     output = []
#     classes = torch.unique(y)
#     for k in classes:
#         grad = torch.zeros(X.size()[1])
#         for i in range(X.size()[0]):
#             if y[i] == k:
#                 indicator = 1
#             else:
#                 indicator = 0
#             grad += X[i] * (indicator - cost_function(Theta, X[i], torch.tensor([k])))
#         grad = grad.unsqueeze(0)
#         grad = grad.t()
#         output.append(-grad)
#     return torch.cat(output, dim=1)
    indicator = torch.zeros((X.size()[0], Theta.size()[1]))
    for i, idx in enumerate(y):
        indicator[i][idx] = 1
    result = - X.t() @ (indicator - classes_probabilities(Theta, X, y))
    return result
    

def softmax_regression_loss(Theta, X, y):
    '''Implementation of the softmax loss function.
        
    Theta is the matrix of parameters, with the parameters of the k-th class in the k-th column
    X contains the data vectors (one vector per row)
    y is a column vector of the targets
    '''
#    # YOUR CODE HERE
#     loss = 0
#     classes = torch.unique(y)
#     for i in range(X.size()[0]):
#         for k in classes:
#             if y[i] == k:
#                 indicator = 1
#             else:
#                 indicator = 0
#             print(indicator)
#             loss += indicator * torch.log(cost_function(Theta, X[i], torch.tensor([k])))
#     return -loss
    values = torch.exp(X @ Theta)
    sums = torch.sum(values, 1)
    log_probs = torch.log(classes_probabilities(Theta, X, y))
    cost = 0
    for i in range(X.size()[1]):
        cost -= log_probs[i][y[i]]
    return cost

# %% [markdown]
# __Use the following code block to confirm that your implementation is correct using gradient checking. If there are problems with your gradient or loss, go back and fix them!:__

# %%
# from torch.autograd import gradcheck
from random import randrange

def grad_check(f, x, analytic_grad, num_checks=10, h=1e-3):
#     print(analytic_grad)
    sum_error = 0
    for i in range(num_checks):
        ix = tuple([randrange(m) for m in x.shape]) #randomly sample value to change
        print("==========================")
        print(ix)
        oldval = x[ix].item()
        x[ix] = oldval + h # increment by h
        fxph = f(x) # evaluate f(x + h)
        x[ix] = oldval - h # increment by h
        fxmh = f(x) # evaluate f(x - h)
        x[ix] = oldval # reset

        grad_numerical = (fxph - fxmh) / (2 * h)
        grad_analytic = analytic_grad[ix]
        rel_error = abs(grad_numerical - grad_analytic) / (abs(grad_numerical) + abs(grad_analytic) + 1e-8)
        sum_error += rel_error
        print('numerical: %f\tanalytic: %f\trelative error: %e' % (grad_numerical, grad_analytic, rel_error))
    return sum_error / num_checks

# Create some test data:
num_classes = 10
features_dim = 20
num_items = 100
torch.manual_seed(7)
Theta = torch.randn((features_dim, num_classes))
X = torch.randn((num_items,features_dim))
y = torch.torch.randint(0, num_classes, (num_items, 1))

# compute the analytic gradient
grad = softmax_regression_loss_grad(Theta, X, y)
# print(grad)
loss = softmax_regression_loss(Theta, X, y)
print(loss)
# run the gradient checker    
grad_check(lambda th: softmax_regression_loss(th, X, y), Theta, grad)
# Out:
# tensor([154.5028])
# ==========================
# (6, 2)
# numerical: -1.120449	analytic: -3.178474	relative error: 4.787303e-01
# ==========================
# (10, 3)
# numerical: -0.145504	analytic: -4.418805	relative error: 9.362429e-01
# ==========================
# (16, 4)
# numerical: 2.009058	analytic: 1.190415	relative error: 2.558680e-01
# ==========================
# (10, 7)
# numerical: -2.532400	analytic: -3.280834	relative error: 1.287466e-01
# ==========================
# (10, 1)
# numerical: -0.283758	analytic: 5.828256	relative error: 1.000000e+00
# ==========================
# (6, 7)
# numerical: 2.825114	analytic: 8.668248	relative error: 5.083921e-01
# ==========================
# (14, 2)
# numerical: -1.750140	analytic: -2.097322	relative error: 9.023661e-02
# ==========================
# (2, 4)
# numerical: -0.099250	analytic: -2.239172	relative error: 9.151133e-01
# ==========================
# (3, 8)
# numerical: -0.143633	analytic: 0.197124	relative error: 1.000000e+00
# ==========================
# (2, 4)
# numerical: -0.099250	analytic: -2.239172	relative error: 9.151133e-01
# tensor([0.6228])

# %%
Theta = torch.Tensor([[1, 0], [0, 1]])
X = torch.Tensor([[1, 0], [0, 1]])
y = torch.LongTensor([[0], [1]])
assert torch.abs(softmax_regression_loss(Theta, X, y) - 0.6265) < 0.0001
grad = softmax_regression_loss_grad(Theta, X, y)
assert torch.torch.allclose(torch.abs(grad/0.2689), torch.ones_like(grad), atol=0.001)

# %% [markdown]
# ## Training Softmax regression with gradient descent on real data
#
# We'll now try gradient descent with our softmax regression using the digits dataset. As before, when we looked at logistic regression, we load the data and create test and training sets. Note that this time we'll use all the classes:

# %%
from sklearn.datasets import load_digits

X, y = (torch.Tensor(z) for z in load_digits(10, True)) #convert to pytorch Tensors
X = torch.cat((X, torch.ones((X.shape[0], 1))), 1) # append a column of 1's to the X's
X /= 255
y = y.reshape(-1, 1) # reshape y into a column vector
y = y.type(torch.LongTensor)

# We're also going to break the data into a training set for computing the regression parameters
# and a test set to evaluate the predictive ability of those parameters
perm = torch.randperm(y.shape[0])
X_train = X[perm[0:260], :]
y_train = y[perm[0:260]]
X_test = X[perm[260:], :]
y_test = y[perm[260:]]

# %% [markdown]
# We now define a simple gradient descent loop to train the model:

# %%
alpha = 0.1
theta_gd = torch.rand((X_train.shape[1], 10))

for e in range(0, 1000):
#     print("Inside")
    gr = softmax_regression_loss_grad(theta_gd, X_train, y_train)
    theta_gd -= alpha * gr
    print("Training Loss: ", softmax_regression_loss(theta_gd, X_train, y_train))
#     print(gr)
    if e%100 == 0:
        print("Training Loss: ", softmax_regression_loss(theta_gd, X_train, y_train))

# Compute the accuracy of the test set
proba = torch.softmax(X_test @ theta_gd, 1)
print(float((proba.argmax(1)-y_test[:,0]==0).sum()) / float(proba.shape[0]))
print()
# Out:
# Training Loss:  tensor([147.9320])
# Training Loss:  tensor([147.9320])
# Training Loss:  tensor([146.0936])
# Training Loss:  tensor([144.3199])
# Training Loss:  tensor([142.6032])
# Training Loss:  tensor([140.9372])
# Training Loss:  tensor([139.3168])
# Training Loss:  tensor([137.7375])
# Training Loss:  tensor([136.1959])
# Training Loss:  tensor([134.6890])
# Training Loss:  tensor([133.2142])
# Training Loss:  tensor([131.7695])
# Training Loss:  tensor([130.3533])
# Training Loss:  tensor([128.9639])
# Training Loss:  tensor([127.6002])
# Training Loss:  tensor([126.2610])
# Training Loss:  tensor([124.9454])
# Training Loss:  tensor([123.6527])
# Training Loss:  tensor([122.3820])
# Training Loss:  tensor([121.1328])
# Training Loss:  tensor([119.9043])
# Training Loss:  tensor([118.6962])
# Training Loss:  tensor([117.5079])
# Training Loss:  tensor([116.3389])
# Training Loss:  tensor([115.1888])
# Training Loss:  tensor([114.0572])
# Training Loss:  tensor([112.9438])
# Training Loss:  tensor([111.8481])
# Training Loss:  tensor([110.7699])
# Training Loss:  tensor([109.7087])
# Training Loss:  tensor([108.6643])
# Training Loss:  tensor([107.6363])
# Training Loss:  tensor([106.6244])
# Training Loss:  tensor([105.6284])
# Training Loss:  tensor([104.6479])
# Training Loss:  tensor([103.6827])
# Training Loss:  tensor([102.7325])
# Training Loss:  tensor([101.7969])
# Training Loss:  tensor([100.8759])
# Training Loss:  tensor([99.9690])
# Training Loss:  tensor([99.0760])
# Training Loss:  tensor([98.1968])
# Training Loss:  tensor([97.3310])
# Training Loss:  tensor([96.4783])
# Training Loss:  tensor([95.6387])
# Training Loss:  tensor([94.8117])
# Training Loss:  tensor([93.9973])
# Training Loss:  tensor([93.1952])
# Training Loss:  tensor([92.4051])
# Training Loss:  tensor([91.6268])
# Training Loss:  tensor([90.8602])
# Training Loss:  tensor([90.1050])
# Training Loss:  tensor([89.3610])
# Training Loss:  tensor([88.6281])
# Training Loss:  tensor([87.9059])
# Training Loss:  tensor([87.1944])
# Training Loss:  tensor([86.4933])
# Training Loss:  tensor([85.8025])
# Training Loss:  tensor([85.1217])
# Training Loss:  tensor([84.4508])
# Training Loss:  tensor([83.7896])
# Training Loss:  tensor([83.1379])
# Training Loss:  tensor([82.4956])
# Training Loss:  tensor([81.8625])
# Training Loss:  tensor([81.2385])
# Training Loss:  tensor([80.6233])
# Training Loss:  tensor([80.0168])
# Training Loss:  tensor([79.4188])
# Training Loss:  tensor([78.8293])
# Training Loss:  tensor([78.2480])
# Training Loss:  tensor([77.6749])
# Training Loss:  tensor([77.1097])
# Training Loss:  tensor([76.5523])
# Training Loss:  tensor([76.0026])
# Training Loss:  tensor([75.4605])
# Training Loss:  tensor([74.9258])
# Training Loss:  tensor([74.3983])
# Training Loss:  tensor([73.8781])
# Training Loss:  tensor([73.3649])
# Training Loss:  tensor([72.8586])
# Training Loss:  tensor([72.3590])
# Training Loss:  tensor([71.8662])
# Training Loss:  tensor([71.3799])
# Training Loss:  tensor([70.9001])
# Training Loss:  tensor([70.4266])
# Training Loss:  tensor([69.9593])
# Training Loss:  tensor([69.4981])
# Training Loss:  tensor([69.0430])
# Training Loss:  tensor([68.5938])
# Training Loss:  tensor([68.1504])
# Training Loss:  tensor([67.7127])
# Training Loss:  tensor([67.2806])
# Training Loss:  tensor([66.8540])
# Training Loss:  tensor([66.4328])
# Training Loss:  tensor([66.0170])
# Training Loss:  tensor([65.6065])
# Training Loss:  tensor([65.2011])
# Training Loss:  tensor([64.8007])
# Training Loss:  tensor([64.4054])
# Training Loss:  tensor([64.0150])
# Training Loss:  tensor([63.6294])
# Training Loss:  tensor([63.2485])
# Training Loss:  tensor([63.2485])
# Training Loss:  tensor([62.8723])
# Training Loss:  tensor([62.5007])
# Training Loss:  tensor([62.1336])
# Training Loss:  tensor([61.7709])
# Training Loss:  tensor([61.4126])
# Training Loss:  tensor([61.0586])
# Training Loss:  tensor([60.7089])
# Training Loss:  tensor([60.3633])
# Training Loss:  tensor([60.0218])
# Training Loss:  tensor([59.6843])
# Training Loss:  tensor([59.3508])
# Training Loss:  tensor([59.0212])
# Training Loss:  tensor([58.6954])
# Training Loss:  tensor([58.3734])
# Training Loss:  tensor([58.0551])
# Training Loss:  tensor([57.7405])
# Training Loss:  tensor([57.4295])
# Training Loss:  tensor([57.1220])
# Training Loss:  tensor([56.8181])
# Training Loss:  tensor([56.5175])
# Training Loss:  tensor([56.2204])
# Training Loss:  tensor([55.9266])
# Training Loss:  tensor([55.6360])
# Training Loss:  tensor([55.3487])
# Training Loss:  tensor([55.0646])
# Training Loss:  tensor([54.7836])
# Training Loss:  tensor([54.5057])
# Training Loss:  tensor([54.2308])
# Training Loss:  tensor([53.9589])
# Training Loss:  tensor([53.6900])
# Training Loss:  tensor([53.4239])
# Training Loss:  tensor([53.1608])
# Training Loss:  tensor([52.9004])
# Training Loss:  tensor([52.6428])
# Training Loss:  tensor([52.3880])
# Training Loss:  tensor([52.1358])
# Training Loss:  tensor([51.8863])
# Training Loss:  tensor([51.6395])
# Training Loss:  tensor([51.3952])
# Training Loss:  tensor([51.1534])
# Training Loss:  tensor([50.9141])
# Training Loss:  tensor([50.6773])
# Training Loss:  tensor([50.4430])
# Training Loss:  tensor([50.2110])
# Training Loss:  tensor([49.9814])
# Training Loss:  tensor([49.7541])
# Training Loss:  tensor([49.5292])
# Training Loss:  tensor([49.3064])
# Training Loss:  tensor([49.0860])
# Training Loss:  tensor([48.8677])
# Training Loss:  tensor([48.6515])
# Training Loss:  tensor([48.4376])
# Training Loss:  tensor([48.2257])
# Training Loss:  tensor([48.0159])
# Training Loss:  tensor([47.8082])
# Training Loss:  tensor([47.6024])
# Training Loss:  tensor([47.3987])
# Training Loss:  tensor([47.1970])
# Training Loss:  tensor([46.9971])
# Training Loss:  tensor([46.7992])
# Training Loss:  tensor([46.6032])
# Training Loss:  tensor([46.4090])
# Training Loss:  tensor([46.2167])
# Training Loss:  tensor([46.0262])
# Training Loss:  tensor([45.8375])
# Training Loss:  tensor([45.6505])
# Training Loss:  tensor([45.4653])
# Training Loss:  tensor([45.2818])
# Training Loss:  tensor([45.1000])
# Training Loss:  tensor([44.9199])
# Training Loss:  tensor([44.7414])
# Training Loss:  tensor([44.5645])
# Training Loss:  tensor([44.3893])
# Training Loss:  tensor([44.2156])
# Training Loss:  tensor([44.0435])
# Training Loss:  tensor([43.8730])
# Training Loss:  tensor([43.7040])
# Training Loss:  tensor([43.5364])
# Training Loss:  tensor([43.3704])
# Training Loss:  tensor([43.2058])
# Training Loss:  tensor([43.0427])
# Training Loss:  tensor([42.8810])
# Training Loss:  tensor([42.7208])
# Training Loss:  tensor([42.5619])
# Training Loss:  tensor([42.4044])
# Training Loss:  tensor([42.2483])
# Training Loss:  tensor([42.0935])
# Training Loss:  tensor([41.9400])
# Training Loss:  tensor([41.7878])
# Training Loss:  tensor([41.6369])
# Training Loss:  tensor([41.4874])
# Training Loss:  tensor([41.3390])
# Training Loss:  tensor([41.1919])
# Training Loss:  tensor([41.0461])
# Training Loss:  tensor([40.9015])
# Training Loss:  tensor([40.7580])
# Training Loss:  tensor([40.6158])
# Training Loss:  tensor([40.4747])
# Training Loss:  tensor([40.3348])
# Training Loss:  tensor([40.1960])
# Training Loss:  tensor([40.1960])
# Training Loss:  tensor([40.0584])
# Training Loss:  tensor([39.9218])
# Training Loss:  tensor([39.7864])
# Training Loss:  tensor([39.6521])
# Training Loss:  tensor([39.5188])
# Training Loss:  tensor([39.3866])
# Training Loss:  tensor([39.2555])
# Training Loss:  tensor([39.1254])
# Training Loss:  tensor([38.9964])
# Training Loss:  tensor([38.8683])
# Training Loss:  tensor([38.7413])
# Training Loss:  tensor([38.6152])
# Training Loss:  tensor([38.4902])
# Training Loss:  tensor([38.3661])
# Training Loss:  tensor([38.2429])
# Training Loss:  tensor([38.1207])
# Training Loss:  tensor([37.9995])
# Training Loss:  tensor([37.8792])
# Training Loss:  tensor([37.7598])
# Training Loss:  tensor([37.6413])
# Training Loss:  tensor([37.5237])
# Training Loss:  tensor([37.4069])
# Training Loss:  tensor([37.2911])
# Training Loss:  tensor([37.1761])
# Training Loss:  tensor([37.0620])
# Training Loss:  tensor([36.9487])
# Training Loss:  tensor([36.8363])
# Training Loss:  tensor([36.7247])
# Training Loss:  tensor([36.6139])
# Training Loss:  tensor([36.5039])
# Training Loss:  tensor([36.3948])
# Training Loss:  tensor([36.2864])
# Training Loss:  tensor([36.1788])
# Training Loss:  tensor([36.0720])
# Training Loss:  tensor([35.9660])
# Training Loss:  tensor([35.8607])
# Training Loss:  tensor([35.7561])
# Training Loss:  tensor([35.6523])
# Training Loss:  tensor([35.5493])
# Training Loss:  tensor([35.4470])
# Training Loss:  tensor([35.3453])
# Training Loss:  tensor([35.2445])
# Training Loss:  tensor([35.1443])
# Training Loss:  tensor([35.0448])
# Training Loss:  tensor([34.9460])
# Training Loss:  tensor([34.8479])
# Training Loss:  tensor([34.7504])
# Training Loss:  tensor([34.6536])
# Training Loss:  tensor([34.5575])
# Training Loss:  tensor([34.4621])
# Training Loss:  tensor([34.3673])
# Training Loss:  tensor([34.2731])
# Training Loss:  tensor([34.1796])
# Training Loss:  tensor([34.0867])
# Training Loss:  tensor([33.9944])
# Training Loss:  tensor([33.9028])
# Training Loss:  tensor([33.8117])
# Training Loss:  tensor([33.7213])
# Training Loss:  tensor([33.6314])
# Training Loss:  tensor([33.5422])
# Training Loss:  tensor([33.4535])
# Training Loss:  tensor([33.3654])
# Training Loss:  tensor([33.2779])
# Training Loss:  tensor([33.1910])
# Training Loss:  tensor([33.1046])
# Training Loss:  tensor([33.0188])
# Training Loss:  tensor([32.9335])
# Training Loss:  tensor([32.8488])
# Training Loss:  tensor([32.7646])
# Training Loss:  tensor([32.6810])
# Training Loss:  tensor([32.5978])
# Training Loss:  tensor([32.5153])
# Training Loss:  tensor([32.4332])
# Training Loss:  tensor([32.3516])
# Training Loss:  tensor([32.2706])
# Training Loss:  tensor([32.1901])
# Training Loss:  tensor([32.1100])
# Training Loss:  tensor([32.0305])
# Training Loss:  tensor([31.9515])
# Training Loss:  tensor([31.8729])
# Training Loss:  tensor([31.7949])
# Training Loss:  tensor([31.7173])
# Training Loss:  tensor([31.6401])
# Training Loss:  tensor([31.5635])
# Training Loss:  tensor([31.4873])
# Training Loss:  tensor([31.4116])
# Training Loss:  tensor([31.3363])
# Training Loss:  tensor([31.2615])
# Training Loss:  tensor([31.1872])
# Training Loss:  tensor([31.1132])
# Training Loss:  tensor([31.0398])
# Training Loss:  tensor([30.9667])
# Training Loss:  tensor([30.8941])
# Training Loss:  tensor([30.8219])
# Training Loss:  tensor([30.7502])
# Training Loss:  tensor([30.6788])
# Training Loss:  tensor([30.6079])
# Training Loss:  tensor([30.5374])
# Training Loss:  tensor([30.4673])
# Training Loss:  tensor([30.3976])
# Training Loss:  tensor([30.3976])
# Training Loss:  tensor([30.3283])
# Training Loss:  tensor([30.2594])
# Training Loss:  tensor([30.1909])
# Training Loss:  tensor([30.1228])
# Training Loss:  tensor([30.0551])
# Training Loss:  tensor([29.9877])
# Training Loss:  tensor([29.9208])
# Training Loss:  tensor([29.8542])
# Training Loss:  tensor([29.7880])
# Training Loss:  tensor([29.7222])
# Training Loss:  tensor([29.6567])
# Training Loss:  tensor([29.5916])
# Training Loss:  tensor([29.5269])
# Training Loss:  tensor([29.4625])
# Training Loss:  tensor([29.3985])
# Training Loss:  tensor([29.3348])
# Training Loss:  tensor([29.2715])
# Training Loss:  tensor([29.2085])
# Training Loss:  tensor([29.1459])
# Training Loss:  tensor([29.0836])
# Training Loss:  tensor([29.0216])
# Training Loss:  tensor([28.9600])
# Training Loss:  tensor([28.8987])
# Training Loss:  tensor([28.8378])
# Training Loss:  tensor([28.7771])
# Training Loss:  tensor([28.7168])
# Training Loss:  tensor([28.6568])
# Training Loss:  tensor([28.5972])
# Training Loss:  tensor([28.5378])
# Training Loss:  tensor([28.4788])
# Training Loss:  tensor([28.4201])
# Training Loss:  tensor([28.3616])
# Training Loss:  tensor([28.3035])
# Training Loss:  tensor([28.2457])
# Training Loss:  tensor([28.1882])
# Training Loss:  tensor([28.1310])
# Training Loss:  tensor([28.0741])
# Training Loss:  tensor([28.0175])
# Training Loss:  tensor([27.9611])
# Training Loss:  tensor([27.9051])
# Training Loss:  tensor([27.8494])
# Training Loss:  tensor([27.7939])
# Training Loss:  tensor([27.7387])
# Training Loss:  tensor([27.6838])
# Training Loss:  tensor([27.6292])
# Training Loss:  tensor([27.5748])
# Training Loss:  tensor([27.5207])
# Training Loss:  tensor([27.4669])
# Training Loss:  tensor([27.4134])
# Training Loss:  tensor([27.3601])
# Training Loss:  tensor([27.3071])
# Training Loss:  tensor([27.2543])
# Training Loss:  tensor([27.2018])
# Training Loss:  tensor([27.1496])
# Training Loss:  tensor([27.0976])
# Training Loss:  tensor([27.0459])
# Training Loss:  tensor([26.9945])
# Training Loss:  tensor([26.9432])
# Training Loss:  tensor([26.8923])
# Training Loss:  tensor([26.8416])
# Training Loss:  tensor([26.7911])
# Training Loss:  tensor([26.7408])
# Training Loss:  tensor([26.6909])
# Training Loss:  tensor([26.6411])
# Training Loss:  tensor([26.5916])
# Training Loss:  tensor([26.5423])
# Training Loss:  tensor([26.4933])
# Training Loss:  tensor([26.4445])
# Training Loss:  tensor([26.3959])
# Training Loss:  tensor([26.3475])
# Training Loss:  tensor([26.2994])
# Training Loss:  tensor([26.2515])
# Training Loss:  tensor([26.2038])
# Training Loss:  tensor([26.1564])
# Training Loss:  tensor([26.1091])
# Training Loss:  tensor([26.0621])
# Training Loss:  tensor([26.0153])
# Training Loss:  tensor([25.9687])
# Training Loss:  tensor([25.9224])
# Training Loss:  tensor([25.8762])
# Training Loss:  tensor([25.8303])
# Training Loss:  tensor([25.7845])
# Training Loss:  tensor([25.7390])
# Training Loss:  tensor([25.6937])
# Training Loss:  tensor([25.6486])
# Training Loss:  tensor([25.6037])
# Training Loss:  tensor([25.5589])
# Training Loss:  tensor([25.5144])
# Training Loss:  tensor([25.4701])
# Training Loss:  tensor([25.4260])
# Training Loss:  tensor([25.3821])
# Training Loss:  tensor([25.3384])
# Training Loss:  tensor([25.2948])
# Training Loss:  tensor([25.2515])
# Training Loss:  tensor([25.2084])
# Training Loss:  tensor([25.1654])
# Training Loss:  tensor([25.1226])
# Training Loss:  tensor([25.0800])
# Training Loss:  tensor([25.0376])
# Training Loss:  tensor([24.9954])
# Training Loss:  tensor([24.9954])
# Training Loss:  tensor([24.9534])
# Training Loss:  tensor([24.9116])
# Training Loss:  tensor([24.8699])
# Training Loss:  tensor([24.8284])
# Training Loss:  tensor([24.7871])
# Training Loss:  tensor([24.7460])
# Training Loss:  tensor([24.7050])
# Training Loss:  tensor([24.6642])
# Training Loss:  tensor([24.6236])
# Training Loss:  tensor([24.5832])
# Training Loss:  tensor([24.5429])
# Training Loss:  tensor([24.5028])
# Training Loss:  tensor([24.4629])
# Training Loss:  tensor([24.4231])
# Training Loss:  tensor([24.3835])
# Training Loss:  tensor([24.3441])
# Training Loss:  tensor([24.3048])
# Training Loss:  tensor([24.2657])
# Training Loss:  tensor([24.2268])
# Training Loss:  tensor([24.1880])
# Training Loss:  tensor([24.1494])
# Training Loss:  tensor([24.1109])
# Training Loss:  tensor([24.0726])
# Training Loss:  tensor([24.0344])
# Training Loss:  tensor([23.9965])
# Training Loss:  tensor([23.9586])
# Training Loss:  tensor([23.9209])
# Training Loss:  tensor([23.8834])
# Training Loss:  tensor([23.8460])
# Training Loss:  tensor([23.8088])
# Training Loss:  tensor([23.7717])
# Training Loss:  tensor([23.7348])
# Training Loss:  tensor([23.6980])
# Training Loss:  tensor([23.6613])
# Training Loss:  tensor([23.6248])
# Training Loss:  tensor([23.5885])
# Training Loss:  tensor([23.5523])
# Training Loss:  tensor([23.5162])
# Training Loss:  tensor([23.4803])
# Training Loss:  tensor([23.4445])
# Training Loss:  tensor([23.4089])
# Training Loss:  tensor([23.3734])
# Training Loss:  tensor([23.3380])
# Training Loss:  tensor([23.3028])
# Training Loss:  tensor([23.2677])
# Training Loss:  tensor([23.2328])
# Training Loss:  tensor([23.1980])
# Training Loss:  tensor([23.1633])
# Training Loss:  tensor([23.1287])
# Training Loss:  tensor([23.0943])
# Training Loss:  tensor([23.0600])
# Training Loss:  tensor([23.0259])
# Training Loss:  tensor([22.9918])
# Training Loss:  tensor([22.9579])
# Training Loss:  tensor([22.9242])
# Training Loss:  tensor([22.8905])
# Training Loss:  tensor([22.8570])
# Training Loss:  tensor([22.8236])
# Training Loss:  tensor([22.7904])
# Training Loss:  tensor([22.7572])
# Training Loss:  tensor([22.7242])
# Training Loss:  tensor([22.6913])
# Training Loss:  tensor([22.6586])
# Training Loss:  tensor([22.6259])
# Training Loss:  tensor([22.5934])
# Training Loss:  tensor([22.5610])
# Training Loss:  tensor([22.5287])
# Training Loss:  tensor([22.4965])
# Training Loss:  tensor([22.4645])
# Training Loss:  tensor([22.4326])
# Training Loss:  tensor([22.4007])
# Training Loss:  tensor([22.3690])
# Training Loss:  tensor([22.3375])
# Training Loss:  tensor([22.3060])
# Training Loss:  tensor([22.2746])
# Training Loss:  tensor([22.2434])
# Training Loss:  tensor([22.2123])
# Training Loss:  tensor([22.1812])
# Training Loss:  tensor([22.1503])
# Training Loss:  tensor([22.1195])
# Training Loss:  tensor([22.0888])
# Training Loss:  tensor([22.0583])
# Training Loss:  tensor([22.0278])
# Training Loss:  tensor([21.9974])
# Training Loss:  tensor([21.9672])
# Training Loss:  tensor([21.9370])
# Training Loss:  tensor([21.9070])
# Training Loss:  tensor([21.8770])
# Training Loss:  tensor([21.8472])
# Training Loss:  tensor([21.8175])
# Training Loss:  tensor([21.7878])
# Training Loss:  tensor([21.7583])
# Training Loss:  tensor([21.7289])
# Training Loss:  tensor([21.6996])
# Training Loss:  tensor([21.6704])
# Training Loss:  tensor([21.6412])
# Training Loss:  tensor([21.6122])
# Training Loss:  tensor([21.5833])
# Training Loss:  tensor([21.5545])
# Training Loss:  tensor([21.5258])
# Training Loss:  tensor([21.5258])
# Training Loss:  tensor([21.4972])
# Training Loss:  tensor([21.4686])
# Training Loss:  tensor([21.4402])
# Training Loss:  tensor([21.4119])
# Training Loss:  tensor([21.3836])
# Training Loss:  tensor([21.3555])
# Training Loss:  tensor([21.3274])
# Training Loss:  tensor([21.2995])
# Training Loss:  tensor([21.2716])
# Training Loss:  tensor([21.2439])
# Training Loss:  tensor([21.2162])
# Training Loss:  tensor([21.1886])
# Training Loss:  tensor([21.1611])
# Training Loss:  tensor([21.1337])
# Training Loss:  tensor([21.1064])
# Training Loss:  tensor([21.0792])
# Training Loss:  tensor([21.0521])
# Training Loss:  tensor([21.0250])
# Training Loss:  tensor([20.9981])
# Training Loss:  tensor([20.9712])
# Training Loss:  tensor([20.9444])
# Training Loss:  tensor([20.9178])
# Training Loss:  tensor([20.8911])
# Training Loss:  tensor([20.8646])
# Training Loss:  tensor([20.8382])
# Training Loss:  tensor([20.8119])
# Training Loss:  tensor([20.7856])
# Training Loss:  tensor([20.7594])
# Training Loss:  tensor([20.7333])
# Training Loss:  tensor([20.7073])
# Training Loss:  tensor([20.6814])
# Training Loss:  tensor([20.6556])
# Training Loss:  tensor([20.6298])
# Training Loss:  tensor([20.6041])
# Training Loss:  tensor([20.5785])
# Training Loss:  tensor([20.5530])
# Training Loss:  tensor([20.5276])
# Training Loss:  tensor([20.5022])
# Training Loss:  tensor([20.4769])
# Training Loss:  tensor([20.4517])
# Training Loss:  tensor([20.4266])
# Training Loss:  tensor([20.4016])
# Training Loss:  tensor([20.3766])
# Training Loss:  tensor([20.3517])
# Training Loss:  tensor([20.3269])
# Training Loss:  tensor([20.3022])
# Training Loss:  tensor([20.2775])
# Training Loss:  tensor([20.2530])
# Training Loss:  tensor([20.2285])
# Training Loss:  tensor([20.2040])
# Training Loss:  tensor([20.1797])
# Training Loss:  tensor([20.1554])
# Training Loss:  tensor([20.1312])
# Training Loss:  tensor([20.1071])
# Training Loss:  tensor([20.0830])
# Training Loss:  tensor([20.0590])
# Training Loss:  tensor([20.0351])
# Training Loss:  tensor([20.0113])
# Training Loss:  tensor([19.9875])
# Training Loss:  tensor([19.9638])
# Training Loss:  tensor([19.9402])
# Training Loss:  tensor([19.9166])
# Training Loss:  tensor([19.8931])
# Training Loss:  tensor([19.8697])
# Training Loss:  tensor([19.8464])
# Training Loss:  tensor([19.8231])
# Training Loss:  tensor([19.7999])
# Training Loss:  tensor([19.7767])
# Training Loss:  tensor([19.7537])
# Training Loss:  tensor([19.7307])
# Training Loss:  tensor([19.7077])
# Training Loss:  tensor([19.6849])
# Training Loss:  tensor([19.6621])
# Training Loss:  tensor([19.6393])
# Training Loss:  tensor([19.6167])
# Training Loss:  tensor([19.5941])
# Training Loss:  tensor([19.5715])
# Training Loss:  tensor([19.5491])
# Training Loss:  tensor([19.5267])
# Training Loss:  tensor([19.5043])
# Training Loss:  tensor([19.4820])
# Training Loss:  tensor([19.4598])
# Training Loss:  tensor([19.4377])
# Training Loss:  tensor([19.4156])
# Training Loss:  tensor([19.3936])
# Training Loss:  tensor([19.3716])
# Training Loss:  tensor([19.3497])
# Training Loss:  tensor([19.3279])
# Training Loss:  tensor([19.3061])
# Training Loss:  tensor([19.2844])
# Training Loss:  tensor([19.2627])
# Training Loss:  tensor([19.2411])
# Training Loss:  tensor([19.2196])
# Training Loss:  tensor([19.1982])
# Training Loss:  tensor([19.1767])
# Training Loss:  tensor([19.1554])
# Training Loss:  tensor([19.1341])
# Training Loss:  tensor([19.1129])
# Training Loss:  tensor([19.0917])
# Training Loss:  tensor([19.0706])
# Training Loss:  tensor([19.0706])
# Training Loss:  tensor([19.0495])
# Training Loss:  tensor([19.0286])
# Training Loss:  tensor([19.0076])
# Training Loss:  tensor([18.9867])
# Training Loss:  tensor([18.9659])
# Training Loss:  tensor([18.9452])
# Training Loss:  tensor([18.9244])
# Training Loss:  tensor([18.9038])
# Training Loss:  tensor([18.8832])
# Training Loss:  tensor([18.8627])
# Training Loss:  tensor([18.8422])
# Training Loss:  tensor([18.8218])
# Training Loss:  tensor([18.8014])
# Training Loss:  tensor([18.7811])
# Training Loss:  tensor([18.7608])
# Training Loss:  tensor([18.7406])
# Training Loss:  tensor([18.7204])
# Training Loss:  tensor([18.7003])
# Training Loss:  tensor([18.6803])
# Training Loss:  tensor([18.6603])
# Training Loss:  tensor([18.6404])
# Training Loss:  tensor([18.6205])
# Training Loss:  tensor([18.6007])
# Training Loss:  tensor([18.5809])
# Training Loss:  tensor([18.5611])
# Training Loss:  tensor([18.5415])
# Training Loss:  tensor([18.5219])
# Training Loss:  tensor([18.5023])
# Training Loss:  tensor([18.4828])
# Training Loss:  tensor([18.4633])
# Training Loss:  tensor([18.4439])
# Training Loss:  tensor([18.4245])
# Training Loss:  tensor([18.4052])
# Training Loss:  tensor([18.3859])
# Training Loss:  tensor([18.3667])
# Training Loss:  tensor([18.3475])
# Training Loss:  tensor([18.3284])
# Training Loss:  tensor([18.3094])
# Training Loss:  tensor([18.2903])
# Training Loss:  tensor([18.2714])
# Training Loss:  tensor([18.2525])
# Training Loss:  tensor([18.2336])
# Training Loss:  tensor([18.2148])
# Training Loss:  tensor([18.1960])
# Training Loss:  tensor([18.1773])
# Training Loss:  tensor([18.1586])
# Training Loss:  tensor([18.1399])
# Training Loss:  tensor([18.1214])
# Training Loss:  tensor([18.1028])
# Training Loss:  tensor([18.0843])
# Training Loss:  tensor([18.0659])
# Training Loss:  tensor([18.0475])
# Training Loss:  tensor([18.0291])
# Training Loss:  tensor([18.0108])
# Training Loss:  tensor([17.9926])
# Training Loss:  tensor([17.9744])
# Training Loss:  tensor([17.9562])
# Training Loss:  tensor([17.9381])
# Training Loss:  tensor([17.9200])
# Training Loss:  tensor([17.9020])
# Training Loss:  tensor([17.8840])
# Training Loss:  tensor([17.8660])
# Training Loss:  tensor([17.8481])
# Training Loss:  tensor([17.8303])
# Training Loss:  tensor([17.8125])
# Training Loss:  tensor([17.7947])
# Training Loss:  tensor([17.7770])
# Training Loss:  tensor([17.7593])
# Training Loss:  tensor([17.7417])
# Training Loss:  tensor([17.7241])
# Training Loss:  tensor([17.7065])
# Training Loss:  tensor([17.6890])
# Training Loss:  tensor([17.6716])
# Training Loss:  tensor([17.6541])
# Training Loss:  tensor([17.6368])
# Training Loss:  tensor([17.6194])
# Training Loss:  tensor([17.6021])
# Training Loss:  tensor([17.5849])
# Training Loss:  tensor([17.5676])
# Training Loss:  tensor([17.5505])
# Training Loss:  tensor([17.5333])
# Training Loss:  tensor([17.5163])
# Training Loss:  tensor([17.4992])
# Training Loss:  tensor([17.4822])
# Training Loss:  tensor([17.4652])
# Training Loss:  tensor([17.4483])
# Training Loss:  tensor([17.4314])
# Training Loss:  tensor([17.4146])
# Training Loss:  tensor([17.3978])
# Training Loss:  tensor([17.3810])
# Training Loss:  tensor([17.3643])
# Training Loss:  tensor([17.3476])
# Training Loss:  tensor([17.3309])
# Training Loss:  tensor([17.3143])
# Training Loss:  tensor([17.2977])
# Training Loss:  tensor([17.2812])
# Training Loss:  tensor([17.2647])
# Training Loss:  tensor([17.2483])
# Training Loss:  tensor([17.2318])
# Training Loss:  tensor([17.2155])
# Training Loss:  tensor([17.2155])
# Training Loss:  tensor([17.1991])
# Training Loss:  tensor([17.1828])
# Training Loss:  tensor([17.1665])
# Training Loss:  tensor([17.1503])
# Training Loss:  tensor([17.1341])
# Training Loss:  tensor([17.1180])
# Training Loss:  tensor([17.1019])
# Training Loss:  tensor([17.0858])
# Training Loss:  tensor([17.0697])
# Training Loss:  tensor([17.0537])
# Training Loss:  tensor([17.0377])
# Training Loss:  tensor([17.0218])
# Training Loss:  tensor([17.0059])
# Training Loss:  tensor([16.9901])
# Training Loss:  tensor([16.9742])
# Training Loss:  tensor([16.9584])
# Training Loss:  tensor([16.9427])
# Training Loss:  tensor([16.9270])
# Training Loss:  tensor([16.9113])
# Training Loss:  tensor([16.8956])
# Training Loss:  tensor([16.8800])
# Training Loss:  tensor([16.8644])
# Training Loss:  tensor([16.8489])
# Training Loss:  tensor([16.8334])
# Training Loss:  tensor([16.8179])
# Training Loss:  tensor([16.8025])
# Training Loss:  tensor([16.7871])
# Training Loss:  tensor([16.7717])
# Training Loss:  tensor([16.7564])
# Training Loss:  tensor([16.7411])
# Training Loss:  tensor([16.7258])
# Training Loss:  tensor([16.7105])
# Training Loss:  tensor([16.6953])
# Training Loss:  tensor([16.6802])
# Training Loss:  tensor([16.6650])
# Training Loss:  tensor([16.6499])
# Training Loss:  tensor([16.6349])
# Training Loss:  tensor([16.6198])
# Training Loss:  tensor([16.6048])
# Training Loss:  tensor([16.5898])
# Training Loss:  tensor([16.5749])
# Training Loss:  tensor([16.5600])
# Training Loss:  tensor([16.5451])
# Training Loss:  tensor([16.5303])
# Training Loss:  tensor([16.5155])
# Training Loss:  tensor([16.5007])
# Training Loss:  tensor([16.4859])
# Training Loss:  tensor([16.4712])
# Training Loss:  tensor([16.4565])
# Training Loss:  tensor([16.4419])
# Training Loss:  tensor([16.4273])
# Training Loss:  tensor([16.4127])
# Training Loss:  tensor([16.3981])
# Training Loss:  tensor([16.3836])
# Training Loss:  tensor([16.3691])
# Training Loss:  tensor([16.3546])
# Training Loss:  tensor([16.3402])
# Training Loss:  tensor([16.3258])
# Training Loss:  tensor([16.3114])
# Training Loss:  tensor([16.2971])
# Training Loss:  tensor([16.2828])
# Training Loss:  tensor([16.2685])
# Training Loss:  tensor([16.2542])
# Training Loss:  tensor([16.2400])
# Training Loss:  tensor([16.2258])
# Training Loss:  tensor([16.2116])
# Training Loss:  tensor([16.1975])
# Training Loss:  tensor([16.1834])
# Training Loss:  tensor([16.1693])
# Training Loss:  tensor([16.1553])
# Training Loss:  tensor([16.1413])
# Training Loss:  tensor([16.1273])
# Training Loss:  tensor([16.1133])
# Training Loss:  tensor([16.0994])
# Training Loss:  tensor([16.0855])
# Training Loss:  tensor([16.0716])
# Training Loss:  tensor([16.0578])
# Training Loss:  tensor([16.0439])
# Training Loss:  tensor([16.0302])
# Training Loss:  tensor([16.0164])
# Training Loss:  tensor([16.0027])
# Training Loss:  tensor([15.9890])
# Training Loss:  tensor([15.9753])
# Training Loss:  tensor([15.9616])
# Training Loss:  tensor([15.9480])
# Training Loss:  tensor([15.9344])
# Training Loss:  tensor([15.9208])
# Training Loss:  tensor([15.9073])
# Training Loss:  tensor([15.8938])
# Training Loss:  tensor([15.8803])
# Training Loss:  tensor([15.8669])
# Training Loss:  tensor([15.8534])
# Training Loss:  tensor([15.8400])
# Training Loss:  tensor([15.8266])
# Training Loss:  tensor([15.8133])
# Training Loss:  tensor([15.8000])
# Training Loss:  tensor([15.7867])
# Training Loss:  tensor([15.7734])
# Training Loss:  tensor([15.7602])
# Training Loss:  tensor([15.7469])
# Training Loss:  tensor([15.7469])
# Training Loss:  tensor([15.7338])
# Training Loss:  tensor([15.7206])
# Training Loss:  tensor([15.7075])
# Training Loss:  tensor([15.6943])
# Training Loss:  tensor([15.6813])
# Training Loss:  tensor([15.6682])
# Training Loss:  tensor([15.6552])
# Training Loss:  tensor([15.6422])
# Training Loss:  tensor([15.6292])
# Training Loss:  tensor([15.6162])
# Training Loss:  tensor([15.6033])
# Training Loss:  tensor([15.5904])
# Training Loss:  tensor([15.5775])
# Training Loss:  tensor([15.5646])
# Training Loss:  tensor([15.5518])
# Training Loss:  tensor([15.5390])
# Training Loss:  tensor([15.5262])
# Training Loss:  tensor([15.5134])
# Training Loss:  tensor([15.5007])
# Training Loss:  tensor([15.4880])
# Training Loss:  tensor([15.4753])
# Training Loss:  tensor([15.4627])
# Training Loss:  tensor([15.4500])
# Training Loss:  tensor([15.4374])
# Training Loss:  tensor([15.4248])
# Training Loss:  tensor([15.4123])
# Training Loss:  tensor([15.3997])
# Training Loss:  tensor([15.3872])
# Training Loss:  tensor([15.3747])
# Training Loss:  tensor([15.3622])
# Training Loss:  tensor([15.3498])
# Training Loss:  tensor([15.3374])
# Training Loss:  tensor([15.3250])
# Training Loss:  tensor([15.3126])
# Training Loss:  tensor([15.3003])
# Training Loss:  tensor([15.2879])
# Training Loss:  tensor([15.2756])
# Training Loss:  tensor([15.2633])
# Training Loss:  tensor([15.2511])
# Training Loss:  tensor([15.2388])
# Training Loss:  tensor([15.2266])
# Training Loss:  tensor([15.2144])
# Training Loss:  tensor([15.2023])
# Training Loss:  tensor([15.1901])
# Training Loss:  tensor([15.1780])
# Training Loss:  tensor([15.1659])
# Training Loss:  tensor([15.1538])
# Training Loss:  tensor([15.1418])
# Training Loss:  tensor([15.1298])
# Training Loss:  tensor([15.1178])
# Training Loss:  tensor([15.1058])
# Training Loss:  tensor([15.0938])
# Training Loss:  tensor([15.0819])
# Training Loss:  tensor([15.0699])
# Training Loss:  tensor([15.0580])
# Training Loss:  tensor([15.0462])
# Training Loss:  tensor([15.0343])
# Training Loss:  tensor([15.0225])
# Training Loss:  tensor([15.0107])
# Training Loss:  tensor([14.9989])
# Training Loss:  tensor([14.9871])
# Training Loss:  tensor([14.9754])
# Training Loss:  tensor([14.9636])
# Training Loss:  tensor([14.9519])
# Training Loss:  tensor([14.9402])
# Training Loss:  tensor([14.9286])
# Training Loss:  tensor([14.9169])
# Training Loss:  tensor([14.9053])
# Training Loss:  tensor([14.8937])
# Training Loss:  tensor([14.8821])
# Training Loss:  tensor([14.8706])
# Training Loss:  tensor([14.8591])
# Training Loss:  tensor([14.8475])
# Training Loss:  tensor([14.8360])
# Training Loss:  tensor([14.8246])
# Training Loss:  tensor([14.8131])
# Training Loss:  tensor([14.8017])
# Training Loss:  tensor([14.7903])
# Training Loss:  tensor([14.7789])
# Training Loss:  tensor([14.7675])
# Training Loss:  tensor([14.7562])
# Training Loss:  tensor([14.7448])
# Training Loss:  tensor([14.7335])
# Training Loss:  tensor([14.7222])
# Training Loss:  tensor([14.7109])
# Training Loss:  tensor([14.6997])
# Training Loss:  tensor([14.6885])
# Training Loss:  tensor([14.6773])
# Training Loss:  tensor([14.6661])
# Training Loss:  tensor([14.6549])
# Training Loss:  tensor([14.6437])
# Training Loss:  tensor([14.6326])
# Training Loss:  tensor([14.6215])
# Training Loss:  tensor([14.6104])
# Training Loss:  tensor([14.5993])
# Training Loss:  tensor([14.5883])
# Training Loss:  tensor([14.5772])
# Training Loss:  tensor([14.5662])
# Training Loss:  tensor([14.5552])
# Training Loss:  tensor([14.5442])
# Training Loss:  tensor([14.5442])
# Training Loss:  tensor([14.5333])
# Training Loss:  tensor([14.5223])
# Training Loss:  tensor([14.5114])
# Training Loss:  tensor([14.5005])
# Training Loss:  tensor([14.4896])
# Training Loss:  tensor([14.4787])
# Training Loss:  tensor([14.4679])
# Training Loss:  tensor([14.4571])
# Training Loss:  tensor([14.4463])
# Training Loss:  tensor([14.4355])
# Training Loss:  tensor([14.4247])
# Training Loss:  tensor([14.4139])
# Training Loss:  tensor([14.4032])
# Training Loss:  tensor([14.3925])
# Training Loss:  tensor([14.3818])
# Training Loss:  tensor([14.3711])
# Training Loss:  tensor([14.3604])
# Training Loss:  tensor([14.3498])
# Training Loss:  tensor([14.3392])
# Training Loss:  tensor([14.3285])
# Training Loss:  tensor([14.3180])
# Training Loss:  tensor([14.3074])
# Training Loss:  tensor([14.2968])
# Training Loss:  tensor([14.2863])
# Training Loss:  tensor([14.2758])
# Training Loss:  tensor([14.2653])
# Training Loss:  tensor([14.2548])
# Training Loss:  tensor([14.2443])
# Training Loss:  tensor([14.2339])
# Training Loss:  tensor([14.2234])
# Training Loss:  tensor([14.2130])
# Training Loss:  tensor([14.2026])
# Training Loss:  tensor([14.1922])
# Training Loss:  tensor([14.1819])
# Training Loss:  tensor([14.1715])
# Training Loss:  tensor([14.1612])
# Training Loss:  tensor([14.1509])
# Training Loss:  tensor([14.1406])
# Training Loss:  tensor([14.1303])
# Training Loss:  tensor([14.1200])
# Training Loss:  tensor([14.1098])
# Training Loss:  tensor([14.0996])
# Training Loss:  tensor([14.0894])
# Training Loss:  tensor([14.0792])
# Training Loss:  tensor([14.0690])
# Training Loss:  tensor([14.0588])
# Training Loss:  tensor([14.0487])
# Training Loss:  tensor([14.0386])
# Training Loss:  tensor([14.0284])
# Training Loss:  tensor([14.0183])
# Training Loss:  tensor([14.0083])
# Training Loss:  tensor([13.9982])
# Training Loss:  tensor([13.9882])
# Training Loss:  tensor([13.9781])
# Training Loss:  tensor([13.9681])
# Training Loss:  tensor([13.9581])
# Training Loss:  tensor([13.9481])
# Training Loss:  tensor([13.9382])
# Training Loss:  tensor([13.9282])
# Training Loss:  tensor([13.9183])
# Training Loss:  tensor([13.9084])
# Training Loss:  tensor([13.8985])
# Training Loss:  tensor([13.8886])
# Training Loss:  tensor([13.8787])
# Training Loss:  tensor([13.8689])
# Training Loss:  tensor([13.8590])
# Training Loss:  tensor([13.8492])
# Training Loss:  tensor([13.8394])
# Training Loss:  tensor([13.8296])
# Training Loss:  tensor([13.8198])
# Training Loss:  tensor([13.8101])
# Training Loss:  tensor([13.8003])
# Training Loss:  tensor([13.7906])
# Training Loss:  tensor([13.7809])
# Training Loss:  tensor([13.7712])
# Training Loss:  tensor([13.7615])
# Training Loss:  tensor([13.7519])
# Training Loss:  tensor([13.7422])
# Training Loss:  tensor([13.7326])
# Training Loss:  tensor([13.7230])
# Training Loss:  tensor([13.7133])
# Training Loss:  tensor([13.7038])
# Training Loss:  tensor([13.6942])
# Training Loss:  tensor([13.6846])
# Training Loss:  tensor([13.6751])
# Training Loss:  tensor([13.6655])
# Training Loss:  tensor([13.6560])
# Training Loss:  tensor([13.6465])
# Training Loss:  tensor([13.6370])
# Training Loss:  tensor([13.6276])
# Training Loss:  tensor([13.6181])
# Training Loss:  tensor([13.6087])
# Training Loss:  tensor([13.5992])
# Training Loss:  tensor([13.5898])
# Training Loss:  tensor([13.5804])
# Training Loss:  tensor([13.5711])
# Training Loss:  tensor([13.5617])
# Training Loss:  tensor([13.5523])
# Training Loss:  tensor([13.5430])
# 0.8985035783994795

# %% [markdown]
# Running the above, you should observe that the training loss decreases over time. The final accuracy on the test set is also printed and should be around 90% (it will depend on the particular training/test splits you generated as well as the initial parameters for the softmax).

# %% [markdown]
# # Overparameterisation in softmax regression
#
# Softmax regression has an unusual property that it has a "redundant" set of parameters. To explain what this means, suppose we take each of our parameter vectors $\theta^{(j)}$, and subtract some fixed vector $\psi$ from it, so that every $\theta^{(j)}$ is now replaced with $\theta^{(j)}−\psi$ (for every $j=1,\dots,k$). Our hypothesis now estimates the class label probabilities as
#
# \begin{align}
# P(y^{(i)} = k | x^{(i)} ; \theta)
# &= \frac{\exp((\theta^{(k)}-\psi)^\top x^{(i)})}{\sum_{j=1}^K \exp( (\theta^{(j)}-\psi)^\top x^{(i)})}  \\
# &= \frac{\exp(\theta^{(k)\top} x^{(i)}) \exp(-\psi^\top x^{(i)})}{\sum_{j=1}^K \exp(\theta^{(j)\top} x^{(i)}) \exp(-\psi^\top x^{(i)})} \\
# &= \frac{\exp(\theta^{(k)\top} x^{(i)})}{\sum_{j=1}^K \exp(\theta^{(j)\top} x^{(i)})}.
# \end{align}
#
# __In other words, subtracting $\psi$ from every $\theta^{(j)}$ does not affect our hypothesis’ predictions at all!__ This shows that softmax regression’s parameters are "redundant". More formally, we say that our softmax model is "overparameterised" meaning that for any hypothesis we might fit to the data, there are multiple parameter settings that give rise to exactly the same hypothesis function $h_\theta$ mapping from inputs $\mathbf{x}$ to the predictions.
#
# Further, if the cost function $J(\theta)$ is minimized by some setting of the parameters $(\theta^{(1)},\theta^{(2)},\dots,\theta^{(k)})$, then it is also minimised by $\theta^{(1)}-\psi,\theta^{(2)}-\psi,\dots,\theta^{(k)}-\psi)$ for any value of $\psi$. Thus, the minimiser of $J(\theta)$ is not unique.
#
# (Interestingly, $J(\theta)$ is still convex, and thus gradient descent will not run into local optima problems. The Hessian is however singular/non-invertible, which causes a straightforward implementation of Newton's method (a second-order optimiser) to run into numerical problems.)
#
# Notice also that by setting $\psi=\theta^{(K)}$, one can always replace $\theta^{(K)}$ with $\theta^{(K)}-\psi=\mathbf{0}$ (the vector of all $0$’s), without affecting the hypothesis. Thus, one could "eliminate" the vector of parameters $\theta^{(K)}$ (or any other $\theta^{(k)}$, for any single value of $k$), without harming the representational power of our hypothesis. Indeed, rather than optimising over the $K \cdot n$ parameters $(\theta^{(1)},\theta^{(2)},\dots,\theta^{(k)})$  (where $\theta^{(k)} \in \mathbb{R}^n$, one can instead set $\theta^{(K)}=\mathbf{0}$  and optimize only with respect to the $(K-1) \cdot n$ remaining parameters.

# %% [markdown]
# __Use the following block to implement the softmax gradients for the case where the final column of the parameters theta is fixed to be zero:__

# %%
import torch

def softmax_regression_loss_grad_0(Theta, X, y):
    '''Implementation of the gradient of the softmax loss function, with the parameters of the
    last class fixed to be zero.
    
    Theta is the matrix of parameters, with the parameters of the k-th class in the k-th column; 
            K-1 classes are included, and the parameters of the last class are implicitly zero.
    X contains the data vectors (one vector per row)
    y is a column vector of the targets
    '''
    
    # add the missing column of zeros:
    Theta = torch.cat((Theta, torch.zeros(Theta.shape[0],1)), 1)

    # YOUR CODE HERE
    indicator = torch.zeros((X.size()[0], Theta.size()[1]))
    for i, idx in enumerate(y):
        indicator[i][idx] = 1
    grad = - X.t() @ (indicator - classes_probabilities(Theta, X, y))
    # remove the last column from the gradients
    grad = grad[0:grad.shape[0], 0:grad.shape[1]-1]
    return grad

# %%
Theta = torch.Tensor([[1, 0], [0, 0]])
X = torch.Tensor([[1, 0], [0, 1]])
y = torch.LongTensor([[0], [1]])

grad = softmax_regression_loss_grad(Theta, X, y)
grad0 = softmax_regression_loss_grad_0(Theta[:,0:grad.shape[1]-1], X, y)
assert torch.torch.allclose(grad[:,0:grad.shape[1]-1], grad0)

# %% [markdown]
# Finally, we can run gradient descent with our reduced paramter gradient function, and confirm that the results are similar to before:

# %%
alpha = 0.1
theta_gd = torch.rand((X_train.shape[1], 9))

for e in range(0, 1000):
    gr = softmax_regression_loss_grad_0(theta_gd, X_train, y_train)
    theta_gd -= alpha * gr

theta_gd = torch.cat((theta_gd, torch.zeros(theta_gd.shape[0], 1)), 1)
proba = torch.softmax(X_test @ theta_gd, 1)
print(float((proba.argmax(1)-y_test[:,0]==0).sum()) / float(proba.shape[0]))
print()
# Out:
# 0.8932986337020169
